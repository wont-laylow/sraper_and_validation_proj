# %%
import pandas as pd

df = pd.read_csv("sample_15_products.csv")

df.head()
# Out:
#                                         product_name       brand  \
# 0  Dr. Althea – Anastatica Skin Conditioning Tone...  Dr. Althea
# 1  Medi-Peel – Hyaluron Rose Peptide 9 Ampoule Ey...        Medi
# 2  COSRX – Clear Fit Master Patch – 1 pack (18 pa...       COSRX
# 3  Anua – Heartleaf LHA Moisture Peeling Gel – 12...        Anua
# 4  COSRX – Advanced Snail Hydrogel Eye Patch – 60...       COSRX
#
#          category                                        ingredients  \
# 0          Toners  ['Anastatica Hierochuntica Extract (Resurrecti...
# 1     Eye Patches                                                 []
# 2  Pimple Patches                                                 []
# 3      Exfoliants  ['Heartleaf (Houttuynia Cordata) Extract', 'LH...
# 4     Eye Patches                                                 []
#
#          size                                          image_url  \
# 0      250 ml  https://qudobeauty.com/wp-content/uploads/2025...
# ...

# %%
df = pd.read_csv("sample_10_products.csv")

# %%
df
# Out:
#                                          product_name       brand  \
# 0   Dr. Althea – Anastatica Skin Conditioning Tone...  Dr. Althea
# 1   Medi-Peel – Hyaluron Rose Peptide 9 Ampoule Ey...        Medi
# 2   COSRX – Clear Fit Master Patch – 1 pack (18 pa...       COSRX
# 3                         SKIN1004 – Spot Cover Patch    SKIN1004
# 4   Anua – Heartleaf LHA Moisture Peeling Gel – 12...        Anua
# 5   COSRX – Advanced Snail Hydrogel Eye Patch – 60...       COSRX
# 6      Anua – Peach 77% Niacin Enriched Cream – 50 ml        Anua
# 7          Anua – Heartleaf 70% Daily Lotion – 200 ml        Anua
# 8           Axis-Y – Vegan Collagen Eye Serum – 10 ml        Axis
# 9    COSRX – Hyaluronic Acid Intensive Cream – 100 ml       COSRX
# 10  Medi-Peel – Peptide 9 Bio Sun Stick Pro SPF50+...        Medi
# 11      Anua – Heartleaf 80% Soothing Ampoule – 30 ml        Anua
# 12  COSRX – Aloe Soothing Sun Cream SPF50 PA+++ – ...       COSRX
# ...

# %%
df["ingredients_len"] = df["ingredients"].apply(
    lambda x: len(eval(x)) if isinstance(x, str) else 0
)

# %%
df["ingredients_len"]
# Out:
# 0     5
# 1     0
# 2     0
# 3     0
# 4     6
# 5     0
# 6     6
# 7     5
# 8     6
# 9     0
# 10    0
# 11    5
# 12    4
# 13    4
# 14    5
# Name: ingredients_len, dtype: int64

# %%
df = pd.read_csv("sample_10_products.csv")

# %%
df
# Out:
#                                         product_name       brand  \
# 0  Dr. Althea – Anastatica Skin Conditioning Tone...  Dr. Althea
# 1  Medi-Peel – Hyaluron Rose Peptide 9 Ampoule Ey...   Medi-Peel
# 2  COSRX – Clear Fit Master Patch – 1 pack (18 pa...       COSRX
# 3                        SKIN1004 – Spot Cover Patch    SKIN1004
# 4  Anua – Heartleaf LHA Moisture Peeling Gel – 12...        Anua
# 5  COSRX – Advanced Snail Hydrogel Eye Patch – 60...       COSRX
# 6     Anua – Peach 77% Niacin Enriched Cream – 50 ml        Anua
# 7         Anua – Heartleaf 70% Daily Lotion – 200 ml        Anua
# 8          Axis-Y – Vegan Collagen Eye Serum – 10 ml      Axis-Y
# 9   COSRX – Hyaluronic Acid Intensive Cream – 100 ml       COSRX
#
#          category                                        ingredients  \
# 0          Toners  ['Anastatica Hierochuntica Extract (Resurrecti...
# 1     Eye Patches  ['hyaluronic acid', 'Peptide 9 Complex', 'rose...
# ...
